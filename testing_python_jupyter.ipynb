# %%
#Title: testing_python_jupyter
#Author: Charles Williams
#Date: 2024-07-25
#Purpose: Python development using Jupyter
#Change: 
import csv

with open(r"C:\Users\Charl\OneDrive\Documents\Finances\Budget\stmt.csv", mode='r') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        print(row)
# Out:
# ['Date', 'Description', 'Amount', 'Running Bal.']
# ['07/24/2023', 'Beginning balance as of 07/24/2023', '', '42,124.52']
# ['07/24/2023', 'Preferred Rewards-ATM Oper Rebate Refund of $2.75', '2.75', '42,127.27']
# ['07/24/2023', 'SKA BREWING CO 07/21 PURCHASE DURANGO CO', '-62.22', '42,065.05']
# ['07/24/2023', 'Tempo Mini Mar 07/22 PURCHASE Durango CO', '-30.29', '42,034.76']
# ['07/24/2023', 'LS OURAY MOUNTAIN 07/22 PURCHASE OURAY CO', '-226.51', '41,808.25']
# ['07/24/2023', 'SQ *THE YANKEE GI 07/22 PURCHASE OURAY CO', '-10.39', '41,797.86']
# ['07/24/2023', 'PAI ISO 07/22 #XXXXX2804 WITHDRWL SILVERTON CO', '-62.75', '41,735.11']
# ['07/24/2023', 'ALBERTSONS #08 07/22 PURCHASE DURANGO CO', '-82.20', '41,652.91']
# ['07/24/2023', 'WAL Wal-Mart S 07/23 PURCHASE DURANGO CO', '-77.26', '41,575.65']
# ['07/24/2023', 'THE GREEN HOUS 07/24 PURCHASE DURANGO CO', '-67.01', '41,508.64']
# ['07/24/2023', 'THE YELLOW CARROT 07/23 PURCHASE DURANGO CO', '-77.64', '41,431.00']
# ...
