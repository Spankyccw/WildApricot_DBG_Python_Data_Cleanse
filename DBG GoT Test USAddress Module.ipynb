# %%
#Title: 
#Purpose: Analyze Durango Botanic Gardens "Gardens on Tour" (GoT) 2024 Data with module usaddress
#Change: ccwilliams 20250913 Initial version
# Date/Name/Change
# 
#import csv
#import datetime
from datetime import date
import logging
import os
import pandas as pd
import sys
import usaddress

#Set up script logging
logging.basicConfig(level=logging.DEBUG,
                    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
                    filename='python_script.log',
                    filemode='w+')
logger = logging.getLogger(__name__)

# Create a logger
logger = logging.getLogger(__name__)

# Log messages at different levels
logger.debug('This is a debug message')
logger.info('This is an info message')
logger.warning('This is a warning message')
logger.error('This is an error message')
logger.critical('This is a critical message')

#Set Variables
date = date.today()
#html_file_path = r"C:\Users\Charl\OneDrive\Documents\HTML\daily.html"

#def open_html_file(html_file_path):
#    return open(html_file_path, 'w+')

def format_address():
    address_string1 = "123 Main Street Suite 100 Chicago, Il 60601" #did not abbr streeet or fix state abbr
    address_string2 = "123 Main St Ste 100 Chicago 60601" # does not translate st into street or St. or anything, does not figure state based on zip (expected)
    parsed_address = usaddress.parse(address_string2)
    print(f'BEFORE Adress String: {address_string2}')
    print()
    print(f'AFTER Parsed Address: {parsed_address}')

def main():
    #Display default path for file access
    print('Display default path for file access')
    # __file__ does not work in all environments so alternate used
    #print(os.path.dirname(os.path.abspath(__file__)))
    default_path = os.getcwd()
    print(default_path)
    print()
    
    format_address()
    
    #fh_html = open(r"C:\Users\Charl\OneDrive\Documents\HTML\daily.html",'w+')
"""    with open_html_file(html_file_path) as fh_html:
        fh_html.write("Testing01234")
        fh_html.write("<!DOCTYPE html>\r\n")
        fh_html.write("<html lang=\"en\">\r\n")
        fh_html.write("  <head>\r\n")
        fh_html.write("    <meta charset=\"UTF-8\">\r\n")
        fh_html.write("    <meta name=\"viewport\" content=\"width=device-width, initial-scale=1.0\>\r\n")
        fh_html.write("    <meta http-equiv=\"X-UA-Compatible\" content=\"ie=edge\">\r\n")
        fh_html.write("    <title>APOD (Astronomy Picture of the Day)</title>\r\n")
        fh_html.write("    <link rel=\"stylesheet\" href=\"style.css\">\r\n")
        fh_html.write("  </head>\r\n")
        fh_html.write("  <body>\r\n")

        fh_html.write("APOD Image of the Day<br>")
"""
if __name__ == "__main__":
    main()
# Out:
# Display default path for file access
# C:\Users\Charl\OneDrive\Documents\Development\Python\DBG
#
# BEFORE Adress String: 123 Main St Ste 100 Chicago 60601
#
# AFTER Parsed Address: [('123', 'AddressNumber'), ('Main', 'StreetName'), ('St', 'StreetNamePostType'), ('Ste', 'OccupancyType'), ('100', 'OccupancyIdentifier'), ('Chicago', 'PlaceName'), ('60601', 'ZipCode')]
